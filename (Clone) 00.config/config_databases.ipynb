# %%
# %sql
CREATE DATABASE IF NOT EXISTS bronze

# %%
# %sql

DESCRIBE DATABASE EXTENDED bronze

# %% [markdown]
# O catálogo ampev está usando o Managed Storage Location do Metastore.
# Ou seja, o storage físico está configurado no nível do Unity Catalog Metastore.
# Com isso, parar descobri onde se encontra o MSL é solicitar uma descrição do catálogo.

# %%
# %sql
DESCRIBE CATALOG EXTENDED ampev;

# %%
# %sql
-- Criação do schema/database SILVER:

CREATE DATABASE IF NOT EXISTS silver

# %%
# %sql
DESCRIBE DATABASE EXTENDED silver
